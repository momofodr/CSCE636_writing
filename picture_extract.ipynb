# %%
import csv
import numpy


with open('/Users/jj9754/Desktop/TAMU20SPRING/CSCE636/ava_train_v2.2.csv', newline='') as f:
    reader = csv.reader(f)
    data = list(reader)

data[1][0]
# Out:
# '-5KQ66BBWC4'

# %%
label_train=[x[6] for x in data]
#print(label_train)
y=-1
video_list=[]
for x in label_train:
    #print(x[6])
    y=y+1
    if (x=='63'):
        #print(0)
        video_list.append(data[y][0])
#print(video_list) 
    # download the video

# %%
video_list=list(set(video_list))
print(video_list)
len(video_list)
# Out:
# ['XF87VL5T0aA', 'IKdBLciu_-A', 'fGgnNCbXZ20', 'zlVkeKC6Ha8', 'gqmmpoO1JrY', '32HR3MnDZ8g', 'YYWdB7h1INo', 'l-jxh8gpxuY', 'N5UD8FGzDek', 'fNcxxBjEOgw', '3_VjIRdXVdM', '_145Aa_xkuE', 'rUYsoIIE37A', 'QMwT7DFA5O4', 'x-6CtPWVi6E', 'CG98XdYsgrA', 'XglAvHaEtHY', 'PmElx9ZVByw', '9HOMUW7QNFc', '-OyDO1g74vc', '_ithRWANKB0', 'JNb4nWexD0I', 'b5pRYl_djbs', 'HVAmkvLrthQ', 'eA55_shhKko', 'lWXhqIAvarw', 'Ksd1JQFHYWA', 't0V4drbYDnc', 'zR725veL-DI', '4Y5qi1gD2Sw', '5LrOQEt_XVM', '8VZEwOCQ8bc', 'U_WzY2k8IBM', 'SHBMiL5f_3Q', 'XV_FF3WC7kA', '7g37N3eoQ9s', 'HV0H6oc4Kvs', 'UsLnxI_zGpY', 'UOfuzrwkclM', 'qrkff49p4E4', 'gjasEUDkbuc', '_-Z6wFjXtGQ', 'tjqCzVjojCo', '9mLYmkonWZQ', '7YpF6DntOYw', 'rJKeqfTlAeY', 'bAVXp1oGjHA', 'phVLLTMzmKk', 'BY3sZmvUp-0', 'z3kgrh0L_80', 'KWoSGtglCms', 'xJmRNZVDDCY', 'xO4ABy2iOQA', '053oq2xB3oU', 'T-Fc9ctuNVI', 'lT1zdTL-3SM', 'pGP_oIdKmRY', '2E_e8JlvTlg', '4ZpjKfu6Cl8', 'K_SpqDJnlps', 'tEoJW9ycmSY', '1ReZIMmD_8E', '2fwni_Kjf2M', 'r2llOyS-BmE', 'oq_bufAhyl8', 'v0L-WkMO3s4', 'uq_HBsvP548', 'b50s4AlOOKY', '2FIHxnZKg6A', 'QaIMUi-elFo', 'TCmNvNLRWrc', '9tyiDEYiWiA', 'wfEOx36N4jA', 'P60OxWahxBQ', 'N0Dt9i9IUNg', 'QotkBTEePI8', 'wogRuPNBUi8', 'phrYEKv0rmw', '9IF8uTRrWAM', 'HKjR70GCRPE', '-XpUuIgyUHE', 'IuPC-z-M9u8', 'jI0HIlSsa3s', 'cWYJHb25EVs', 'C3qk4yAMANk', 'mfsbYdLx9wE', 'AYebXQ8eUkM', 'cc4y-yYm5Ao', 'PNZQ2UJfyQE', 'Vmef_8MY46w', '_Ca3gOdOHxU', 'LrDT25hmApw', 'vfjywN5CN0Y', 'BCiuXAuCKAU', 'OfMdakd4bHI']
# 95

# %%
dic=dict.fromkeys(video_list)
for x in data:
    if x[6]=='63':
        if dic[x[0]]:
            dic[x[0]].append(int(x[1]))
        else:
            dic[x[0]]=[int(x[1])]
print(dic.get('XglAvHaEtHY'))
# Out:
# [1289, 1290, 1291, 1292, 1293, 1294, 1295, 1296, 1297, 1298, 1299, 1300, 1301, 1302, 1307, 1328, 1343, 1344, 1345]

# %%
import numpy as np
dic_no=dict.fromkeys(video_list)
for x in data:
    if x[0] in dic_no:
        if x[1] not in dic.get(x[0]):
            ran=numpy.random.choice(numpy.arange(0, 2), p=[0.005, 0.995])
            if ran==0:
                if dic_no[x[0]]:
                    dic_no[x[0]].append(int(x[1]))
                else:
                    dic_no[x[0]]=[int(x[1])]
#print(dic_no.get('XglAvHaEtHY'))

# %%
if x[0] in dic_no:
        if x[1] not in dic.get(x[0]):
            if dic[x[0]]:
                dic[x[0]].append(int(x[1]))
            else:
                dic[x[0]]=[int(x[1])]

# %%
import os
folder1= 'train_writing'  
os.mkdir(folder1)

# %%
folder2='training_nowriting'
os.mkdir(folder2)

# %%
import requests
i=0
count=0
count_no=0
for name in video_list:
    j=str(i)
    request1 = requests.get("https://s3.amazonaws.com/ava-dataset/trainval/"+name+'.mp4')
    request2 = requests.get("https://s3.amazonaws.com/ava-dataset/trainval/"+name+'.mkv')
    request3 = requests.get("https://s3.amazonaws.com/ava-dataset/trainval/"+name+'.webm')
    if request1.status_code == 200:
        open('train'+j+'.mp4', 'wb').write(request1.content)
        video_name='train'+j+'.mp4'
    elif request2.status_code == 200:
        open('train'+j+'.mkv', 'wb').write(request2.content)
        video_name='train'+j+'.mkv'
        #print('Web site does not exist') 
    else:
        open('train'+j+'.webm', 'wb').write(request3.content)
        video_name='train'+j+'.webm'
    
    for x in dic.get(name):
        cap = cv2.VideoCapture(video_name) #video\_name is the video being called
        cap.set(0,x*1000); # Where frame\_no is the frame you want
        ret, frame = cap.read() # Read the frame
        print(ret)
        cv2.imwrite(os.path.join(folder1,"frame{:d}.jpg".format(count)), frame)
        count=count+1
    for i in dic_no.get(name):
        cap_no = cv2.VideoCapture(video_name) #video\_name is the video being called
        cap_no.set(0,i*1000); # Where frame\_no is the frame you want
        ret, frame = cap.read() # Read the frame
        print("nowriting",ret)
        cv2.imwrite(os.path.join(folder2,"frame{:d}.jpg".format(count_no)), frame)
        count_no=count_no+1
    os.remove(video_name)
    i=i+1
    print(name,i)
# Out:
# True
# True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# XF87VL5T0aA 1734
# True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# IKdBLciu_-A 1699
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# fGgnNCbXZ20 1680
# True
# True
# True
# True
# True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# zlVkeKC6Ha8 1776
# True
# True
# True
# True
# True
# True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# gqmmpoO1JrY 1722
# True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# 32HR3MnDZ8g 1474
# True
# True
# True
# True
# True
# True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# YYWdB7h1INo 1785
# True
# True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# l-jxh8gpxuY 1668
# True
# True
# True
# True
# True
# True
# True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# N5UD8FGzDek 1789
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# fNcxxBjEOgw 1791
# True
# True
# True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
# nowriting True
#